# %%
import json 
import pickle

import os
import pandas as pd

import warnings
warnings.filterwarnings(action='ignore')

from tqdm import tqdm, notebook

import pandas as pd
import numpy as np 
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC

from xgboost import XGBClassifier
#from lightgbm import LGBMClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import VotingClassifier

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn import model_selection

# from preprocess import feature_select, sample_generate , replace_outlier
# from scaling import standardize_select, normalize_select
# from load import dataloader

from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# %%
pd.read_pickle('./cols/selected_cols1_ensemble2_SVC.pkl')
# Out:
#                                   0                               1  \
# 0    ENTREZ:144568|HGNC:23336|A2ML1    ENTREZ:653145|HGNC:546|ANXA8
# 1      ENTREZ:653145|HGNC:546|ANXA8  ENTREZ:144568|HGNC:23336|A2ML1
# 2     ENTREZ:388743|HGNC:1485|CAPN8    ENTREZ:1294|HGNC:2214|COL7A1
# 3      ENTREZ:634|HGNC:1814|CEACAM1  ENTREZ:10144|HGNC:19367|FAM13A
# 4      ENTREZ:2498|HGNC:3990|FTH1P3  ENTREZ:79170|HGNC:28149|PRR15L
# 5    ENTREZ:79170|HGNC:28149|PRR15L    ENTREZ:27134|HGNC:11829|TJP3
# 6  ENTREZ:120224|HGNC:25194|TMEM45B       ENTREZ:8714|HGNC:54|ABCC3
# 7       ENTREZ:8745|HGNC:202|ADAM23   ENTREZ:23527|HGNC:16469|ACAP2
# 8        ENTREZ:1173|HGNC:564|AP2M1   ENTREZ:51703|HGNC:16526|ACSL5
# 9     ENTREZ:79616|HGNC:25876|CCNJL      ENTREZ:1173|HGNC:564|AP2M1
#
#                                   2                                   3  \
# 0    ENTREZ:144568|HGNC:23336|A2ML1      ENTREZ:144568|HGNC:23336|A2ML1
# 1     ENTREZ:388743|HGNC:1485|CAPN8  ENTREZ:10610|HGNC:10867|ST6GALNAC2
# 2      ENTREZ:653145|HGNC:546|ANXA8       ENTREZ:23527|HGNC:16469|ACAP2
# 3    ENTREZ:79170|HGNC:28149|PRR15L          ENTREZ:1173|HGNC:564|AP2M1
# 4        ENTREZ:1173|HGNC:564|AP2M1         ENTREZ:810|HGNC:1452|CALML3
# 5   ENTREZ:151354|HGNC:20743|LRATD1       ENTREZ:388743|HGNC:1485|CAPN8
# 6      ENTREZ:2498|HGNC:3990|FTH1P3       ENTREZ:57007|HGNC:23692|ACKR3
# 7      ENTREZ:53836|HGNC:4538|GPR87          ENTREZ:1825|HGNC:3037|DSC3
# 8    ENTREZ:50810|HGNC:24937|HDGFL3     ENTREZ:84102|HGNC:31045|SLC41A2
# 9  ENTREZ:51170|HGNC:22960|HSD17B11        ENTREZ:27324|HGNC:11972|TOX3
#
#                                 4
# 0    ENTREZ:653145|HGNC:546|ANXA8
# 1   ENTREZ:51703|HGNC:16526|ACSL5
# 2   ENTREZ:57538|HGNC:17574|ALPK3
# 3    ENTREZ:6928|HGNC:11630|HNF1B
# 4  ENTREZ:256764|HGNC:26790|WDR72
# 5      ENTREZ:1173|HGNC:564|AP2M1
# 6        ENTREZ:415|HGNC:719|ARSL
# 7   ENTREZ:388743|HGNC:1485|CAPN8
# 8   ENTREZ:57007|HGNC:23692|ACKR3
# 9      ENTREZ:3852|HGNC:6442|KRT5

# %% [markdown]
# # validation results

# %%
#ensemble
results_ran_es = pd.read_pickle('./logs/validation_results1_ensemble_Ran.pkl')
results_knn_es = pd.read_pickle('./logs/validation_results1_ensemble_KNN.pkl')
results_log_es = pd.read_pickle('./logs/validation_results1_ensemble_Log.pkl')
results_svc_es = pd.read_pickle('./logs/validation_results1_ensemble_SVC.pkl')
results_ada_es = pd.read_pickle('./logs/validation_results1_ensemble_Ada.pkl')
results_gnb_es = pd.read_pickle('./logs/validation_results1_ensemble_GNB.pkl')
results_bag_es = pd.read_pickle('./logs/validation_results1_ensemble_Bag.pkl')
#feature importances
results_ran_fi = pd.read_pickle('./logs/validation_results1_feature_importances_Ran.pkl')
results_knn_fi = pd.read_pickle('./logs/validation_results1_feature_importances_KNN.pkl')
results_log_fi = pd.read_pickle('./logs/validation_results1_feature_importances_Log.pkl')
results_svc_fi = pd.read_pickle('./logs/validation_results1_feature_importances_SVC.pkl')
results_ada_fi = pd.read_pickle('./logs/validation_results1_feature_importances_Ada.pkl')
results_gnb_fi = pd.read_pickle('./logs/validation_results1_feature_importances_GNB.pkl')
results_bag_fi = pd.read_pickle('./logs/validation_results1_feature_importances_Bag.pkl')
#rfe
results_ran_rfe = pd.read_pickle('./logs/validation_results1_rfe_Ran.pkl')
results_knn_rfe = pd.read_pickle('./logs/validation_results1_rfe_KNN.pkl')
results_log_rfe = pd.read_pickle('./logs/validation_results1_rfe_Log.pkl')
results_svc_rfe = pd.read_pickle('./logs/validation_results1_rfe_SVC.pkl')
results_ada_rfe = pd.read_pickle('./logs/validation_results1_rfe_Ada.pkl')
results_gnb_rfe = pd.read_pickle('./logs/validation_results1_rfe_GNB.pkl')
results_bag_rfe = pd.read_pickle('./logs/validation_results1_rfe_Bag.pkl')
#selectkbest
results_ran_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_Ran.pkl')
results_knn_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_KNN.pkl')
results_log_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_Log.pkl')
results_svc_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_SVC.pkl')
results_ada_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_Ada.pkl')
results_gnb_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_GNB.pkl')
results_bag_sk = pd.read_pickle('./logs/validation_results1_SelectKBest_Bag.pkl')
#shap1
results_ran_sh1 = pd.read_pickle('./logs/validation_results1_shap1_Ran.pkl')
results_knn_sh1= pd.read_pickle('./logs/validation_results1_shap1_KNN.pkl')
results_log_sh1 = pd.read_pickle('./logs/validation_results1_shap1_Log.pkl')
results_svc_sh1 = pd.read_pickle('./logs/validation_results1_shap1_SVC.pkl')
results_ada_sh1 = pd.read_pickle('./logs/validation_results1_shap1_Ada.pkl')
results_gnb_sh1 = pd.read_pickle('./logs/validation_results1_shap1_GNB.pkl')
results_bag_sh1 = pd.read_pickle('./logs/validation_results1_shap1_Bag.pkl')
#shap2
results_ran_sh2 = pd.read_pickle('./logs/validation_results1_shap2_Ran.pkl')
results_knn_sh2= pd.read_pickle('./logs/validation_results1_shap2_KNN.pkl')
results_log_sh2 = pd.read_pickle('./logs/validation_results1_shap2_Log.pkl')
results_svc_sh2 = pd.read_pickle('./logs/validation_results1_shap2_SVC.pkl')
results_ada_sh2 = pd.read_pickle('./logs/validation_results1_shap2_Ada.pkl')
results_gnb_sh2 = pd.read_pickle('./logs/validation_results1_shap2_GNB.pkl')
results_bag_sh2 = pd.read_pickle('./logs/validation_results1_shap2_Bag.pkl')
#ensemble2
results_ran_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_Ran.pkl')
results_knn_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_KNN.pkl')
results_log_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_Log.pkl')
results_svc_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_SVC.pkl')
results_ada_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_Ada.pkl')
results_gnb_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_GNB.pkl')
results_bag_es2 = pd.read_pickle('./logs/validation_results1_ensemble2_Bag.pkl')

# %%
df_results_es2 = pd.concat([results_ran_es2, results_knn_es2, results_log_es2, results_svc_es2, results_ada_es2, results_gnb_es2, results_bag_es2])

import numpy as np

df_acc_es2 = df_results_es2.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_es2['mean'] = np.mean(df_acc_es2, axis = 1)
df_acc_es2['fsmethod'] = 'ensemble2'
df_acc_es2.set_index('fsmethod',inplace = True)

# %%
df_acc_es2
# Out:
# iter      model         0         1         2         3         4      mean
# fsmethod
# ensemble2   Ada  0.823529  0.813725  0.828431  0.827586  0.817734  0.822201
# ensemble2   Bag  0.833333  0.838235  0.887255  0.822660  0.842365  0.844770
# ensemble2   GNB  0.808824  0.852941  0.843137  0.807882  0.812808  0.825118
# ensemble2   KNN  0.848039  0.813725  0.852941  0.817734  0.807882  0.828064
# ensemble2   Log  0.789216  0.828431  0.843137  0.793103  0.798030  0.810383
# ensemble2   Ran  0.862745  0.857843  0.897059  0.842365  0.847291  0.861460
# ensemble2   SVC  0.833333  0.848039  0.848039  0.793103  0.837438  0.831991

# %%
df_results_sh1 = pd.concat([results_ran_sh1, results_knn_sh1, results_log_sh1, results_svc_sh1, results_ada_sh1, results_gnb_sh1, results_bag_sh1])

import numpy as np

df_acc_sh1 = df_results_sh1.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_sh1['mean'] = np.mean(df_acc_sh1, axis = 1)
df_acc_sh1['fsmethod'] = 'shap1'
df_acc_sh1.set_index('fsmethod',inplace = True)

# %%
df_acc_sh1
# Out:
# iter     model         0         1         2         3         4      mean
# fsmethod
# shap1      Ada  0.857843  0.843137  0.843137  0.817734  0.798030  0.831976
# shap1      Bag  0.848039  0.852941  0.843137  0.842365  0.837438  0.844784
# shap1      GNB  0.862745  0.857843  0.828431  0.837438  0.783251  0.833942
# shap1      KNN  0.843137  0.843137  0.852941  0.832512  0.832512  0.840848
# shap1      Log  0.862745  0.857843  0.833333  0.832512  0.832512  0.843789
# shap1      Ran  0.862745  0.877451  0.882353  0.842365  0.852217  0.863426
# shap1      SVC  0.872549  0.857843  0.848039  0.822660  0.837438  0.847706

# %%
df_results_sh2 = pd.concat([results_ran_sh2, results_knn_sh2, results_log_sh2, results_svc_sh2, results_ada_sh2, results_gnb_sh2, results_bag_sh2])

import numpy as np

df_acc_sh2 = df_results_sh2.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_sh2['mean'] = np.mean(df_acc_sh2, axis = 1)
df_acc_sh2['fsmethod'] = 'shap2'
df_acc_sh2.set_index('fsmethod',inplace = True)

# %%
df_acc_sh2
# Out:
# iter     model         0         1         2         3         4      mean
# fsmethod
# shap2      Ada  0.838235  0.852941  0.862745  0.837438  0.852217  0.848715
# shap2      Bag  0.857843  0.862745  0.857843  0.807882  0.827586  0.842780
# shap2      GNB  0.848039  0.857843  0.828431  0.807882  0.822660  0.832971
# shap2      KNN  0.838235  0.848039  0.867647  0.802956  0.817734  0.834922
# shap2      Log  0.828431  0.852941  0.843137  0.817734  0.832512  0.834951
# shap2      Ran  0.843137  0.877451  0.862745  0.827586  0.866995  0.855583
# shap2      SVC  0.852941  0.848039  0.848039  0.812808  0.832512  0.838868

# %%
df_results_es = pd.concat([results_ran_es, results_knn_es, results_log_es, results_svc_es, results_ada_es, results_gnb_es, results_bag_es])

import numpy as np

df_acc_es = df_results_es.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_es['mean'] = np.mean(df_acc_es, axis = 1)
df_acc_es['fsmethod'] = 'ensemble'
df_acc_es.set_index('fsmethod',inplace = True)

# %%
df_acc_es
# Out:
# iter     model         0         1         2         3         4      mean
# fsmethod
# ensemble   Ada  0.862745  0.838235  0.848039  0.812808  0.798030  0.831971
# ensemble   Bag  0.828431  0.857843  0.857843  0.822660  0.842365  0.841828
# ensemble   GNB  0.823529  0.799020  0.852941  0.778325  0.812808  0.813325
# ensemble   KNN  0.848039  0.813725  0.838235  0.837438  0.822660  0.832020
# ensemble   Log  0.833333  0.828431  0.872549  0.807882  0.822660  0.832971
# ensemble   Ran  0.862745  0.848039  0.862745  0.837438  0.847291  0.851652
# ensemble   SVC  0.867647  0.838235  0.848039  0.822660  0.812808  0.837878

# %%
df_results_fi = pd.concat([results_ran_fi, results_knn_fi, results_log_fi, results_svc_fi, results_ada_fi, results_gnb_fi, results_bag_fi])

import numpy as np

df_acc_fi = df_results_fi.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_fi['mean'] = np.mean(df_acc_fi, axis = 1)
df_acc_fi['fsmethod'] = 'feature_importance'
df_acc_fi.set_index('fsmethod', inplace = True)

# %%
df_acc_fi
# Out:
# iter               model         0         1         2         3         4  \
# fsmethod
# feature_importance   Ada  0.833333  0.848039  0.857843  0.738916  0.832512
# feature_importance   Bag  0.838235  0.843137  0.848039  0.817734  0.812808
# feature_importance   GNB  0.843137  0.818627  0.828431  0.793103  0.837438
# feature_importance   KNN  0.872549  0.882353  0.823529  0.812808  0.817734
# feature_importance   Log  0.862745  0.818627  0.852941  0.812808  0.837438
# feature_importance   Ran  0.843137  0.882353  0.852941  0.827586  0.862069
# feature_importance   SVC  0.862745  0.857843  0.838235  0.812808  0.842365
#
# iter                    mean
# fsmethod
# feature_importance  0.822129
# feature_importance  0.831991
# feature_importance  0.824148
# feature_importance  0.841795
# feature_importance  0.836912
# feature_importance  0.853617
# feature_importance  0.842799

# %%
df_results_rfe = pd.concat([results_ran_rfe, results_knn_rfe, results_log_rfe, results_svc_rfe, results_ada_rfe, results_gnb_rfe, results_bag_rfe])

import numpy as np

df_acc_rfe = df_results_rfe.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_rfe['mean'] = np.mean(df_acc_rfe, axis = 1)
df_acc_rfe['fsmethod'] = 'rfe'
df_acc_rfe.set_index('fsmethod', inplace = True)

# %%
df_acc_rfe
# Out:
# iter     model         0         1         2         3         4      mean
# fsmethod
# rfe        Ada  0.808824  0.769608  0.799020  0.773399  0.822660  0.794702
# rfe        Bag  0.818627  0.754902  0.852941  0.714286  0.842365  0.796624
# rfe        GNB  0.823529  0.725490  0.818627  0.704433  0.842365  0.782889
# rfe        KNN  0.843137  0.740196  0.823529  0.753695  0.817734  0.795658
# rfe        Log  0.813725  0.730392  0.833333  0.758621  0.832512  0.793717
# rfe        Ran  0.818627  0.769608  0.848039  0.763547  0.842365  0.808437
# rfe        SVC  0.808824  0.764706  0.833333  0.763547  0.847291  0.803540

# %%
df_results_sk = pd.concat([results_ran_sk, results_knn_sk, results_log_sk, results_svc_sk, results_ada_sk, results_gnb_sk, results_bag_sk])

import numpy as np

df_acc_sk = df_results_sk.pivot_table(index = 'model', columns = 'iter')['val_acc'].reset_index()
df_acc_sk['mean'] = np.mean(df_acc_sk, axis = 1)
df_acc_sk['fsmethod'] = 'selectkbest'
df_acc_sk.set_index('fsmethod',inplace = True)

# %%
df_acc_sk
# Out:
# iter        model         0         1         2         3         4      mean
# fsmethod
# selectkbest   Ada  0.857843  0.838235  0.813725  0.837438  0.812808  0.832010
# selectkbest   Bag  0.833333  0.838235  0.848039  0.798030  0.817734  0.827074
# selectkbest   GNB  0.867647  0.857843  0.852941  0.817734  0.832512  0.845736
# selectkbest   KNN  0.843137  0.833333  0.862745  0.832512  0.832512  0.840848
# selectkbest   Log  0.867647  0.867647  0.848039  0.822660  0.842365  0.849672
# selectkbest   Ran  0.877451  0.882353  0.872549  0.842365  0.857143  0.866372
# selectkbest   SVC  0.862745  0.867647  0.862745  0.822660  0.842365  0.851632

# %% [markdown]
# # total results dataframe

# %%
total_df = pd.concat([df_acc_es, df_acc_sk, df_acc_fi, df_acc_rfe,df_acc_sh1,df_acc_sh2,df_acc_es2])

# %%
total_df
# Out:
# iter               model         0         1         2         3         4  \
# fsmethod
# ensemble             Ada  0.862745  0.838235  0.848039  0.812808  0.798030
# ensemble             Bag  0.828431  0.857843  0.857843  0.822660  0.842365
# ensemble             GNB  0.823529  0.799020  0.852941  0.778325  0.812808
# ensemble             KNN  0.848039  0.813725  0.838235  0.837438  0.822660
# ensemble             Log  0.833333  0.828431  0.872549  0.807882  0.822660
# ensemble             Ran  0.862745  0.848039  0.862745  0.837438  0.847291
# ensemble             SVC  0.867647  0.838235  0.848039  0.822660  0.812808
# selectkbest          Ada  0.857843  0.838235  0.813725  0.837438  0.812808
# selectkbest          Bag  0.833333  0.838235  0.848039  0.798030  0.817734
# selectkbest          GNB  0.867647  0.857843  0.852941  0.817734  0.832512
# selectkbest          KNN  0.843137  0.833333  0.862745  0.832512  0.832512
# selectkbest          Log  0.867647  0.867647  0.848039  0.822660  0.842365
# selectkbest          Ran  0.877451  0.882353  0.872549  0.842365  0.857143
# selectkbest          SVC  0.862745  0.867647  0.862745  0.822660  0.842365
# feature_importance   Ada  0.833333  0.848039  0.857843  0.738916  0.832512
# feature_importance   Bag  0.838235  0.843137  0.848039  0.817734  0.812808
# feature_importance   GNB  0.843137  0.818627  0.828431  0.793103  0.837438
# feature_importance   KNN  0.872549  0.882353  0.823529  0.812808  0.817734
# feature_importance   Log  0.862745  0.818627  0.852941  0.812808  0.837438
# feature_importance   Ran  0.843137  0.882353  0.852941  0.827586  0.862069
# feature_importance   SVC  0.862745  0.857843  0.838235  0.812808  0.842365
# rfe                  Ada  0.808824  0.769608  0.799020  0.773399  0.822660
# rfe                  Bag  0.818627  0.754902  0.852941  0.714286  0.842365
# rfe                  GNB  0.823529  0.725490  0.818627  0.704433  0.842365
# rfe                  KNN  0.843137  0.740196  0.823529  0.753695  0.817734
# rfe                  Log  0.813725  0.730392  0.833333  0.758621  0.832512
# rfe                  Ran  0.818627  0.769608  0.848039  0.763547  0.842365
# rfe                  SVC  0.808824  0.764706  0.833333  0.763547  0.847291
# shap1                Ada  0.857843  0.843137  0.843137  0.817734  0.798030
# shap1                Bag  0.848039  0.852941  0.843137  0.842365  0.837438
# shap1                GNB  0.862745  0.857843  0.828431  0.837438  0.783251
# shap1                KNN  0.843137  0.843137  0.852941  0.832512  0.832512
# shap1                Log  0.862745  0.857843  0.833333  0.832512  0.832512
# shap1                Ran  0.862745  0.877451  0.882353  0.842365  0.852217
# shap1                SVC  0.872549  0.857843  0.848039  0.822660  0.837438
# shap2                Ada  0.838235  0.852941  0.862745  0.837438  0.852217
# shap2                Bag  0.857843  0.862745  0.857843  0.807882  0.827586
# shap2                GNB  0.848039  0.857843  0.828431  0.807882  0.822660
# shap2                KNN  0.838235  0.848039  0.867647  0.802956  0.817734
# shap2                Log  0.828431  0.852941  0.843137  0.817734  0.832512
# shap2                Ran  0.843137  0.877451  0.862745  0.827586  0.866995
# shap2                SVC  0.852941  0.848039  0.848039  0.812808  0.832512
# ensemble2            Ada  0.823529  0.813725  0.828431  0.827586  0.817734
# ensemble2            Bag  0.833333  0.838235  0.887255  0.822660  0.842365
# ensemble2            GNB  0.808824  0.852941  0.843137  0.807882  0.812808
# ensemble2            KNN  0.848039  0.813725  0.852941  0.817734  0.807882
# ensemble2            Log  0.789216  0.828431  0.843137  0.793103  0.798030
# ensemble2            Ran  0.862745  0.857843  0.897059  0.842365  0.847291
# ensemble2            SVC  0.833333  0.848039  0.848039  0.793103  0.837438
#
# iter                    mean
# fsmethod
# ensemble            0.831971
# ensemble            0.841828
# ensemble            0.813325
# ensemble            0.832020
# ensemble            0.832971
# ensemble            0.851652
# ensemble            0.837878
# selectkbest         0.832010
# selectkbest         0.827074
# selectkbest         0.845736
# selectkbest         0.840848
# selectkbest         0.849672
# selectkbest         0.866372
# selectkbest         0.851632
# feature_importance  0.822129
# feature_importance  0.831991
# feature_importance  0.824148
# feature_importance  0.841795
# feature_importance  0.836912
# feature_importance  0.853617
# feature_importance  0.842799
# rfe                 0.794702
# rfe                 0.796624
# rfe                 0.782889
# rfe                 0.795658
# rfe                 0.793717
# rfe                 0.808437
# rfe                 0.803540
# shap1               0.831976
# shap1               0.844784
# shap1               0.833942
# shap1               0.840848
# shap1               0.843789
# shap1               0.863426
# shap1               0.847706
# shap2               0.848715
# shap2               0.842780
# shap2               0.832971
# shap2               0.834922
# shap2               0.834951
# shap2               0.855583
# shap2               0.838868
# ensemble2           0.822201
# ensemble2           0.844770
# ensemble2           0.825118
# ensemble2           0.828064
# ensemble2           0.810383
# ensemble2           0.861460
# ensemble2           0.831991

# %%
total_df.index.unique()
# Out:
# Index(['ensemble', 'selectkbest', 'feature_importance', 'rfe', 'shap1',
#        'shap2', 'ensemble2'],
#       dtype='object', name='fsmethod')

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='Ada'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='Ada'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=5.0, pvalue=1.0)
# ensemble vs  feature_importance WilcoxonResult(statistic=7.0, pvalue=1.0)
# ensemble vs  rfe WilcoxonResult(statistic=1.0, pvalue=0.125)
# ensemble vs  shap1 WilcoxonResult(statistic=4.5, pvalue=0.8539232992870668)
# ensemble vs  shap2 WilcoxonResult(statistic=3.0, pvalue=0.3125)
# ensemble vs  ensemble2 WilcoxonResult(statistic=4.0, pvalue=0.4375)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='Bag'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='Bag'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=1.0, pvalue=0.125)
# ensemble vs  feature_importance WilcoxonResult(statistic=2.5, pvalue=0.1875)
# ensemble vs  rfe WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
# ensemble vs  shap1 WilcoxonResult(statistic=6.0, pvalue=0.8125)
# ensemble vs  shap2 WilcoxonResult(statistic=5.0, pvalue=1.0)
# ensemble vs  ensemble2 WilcoxonResult(statistic=2.0, pvalue=0.5929800980174267)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='GNB'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='GNB'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)
# ensemble vs  feature_importance WilcoxonResult(statistic=4.0, pvalue=0.4375)
# ensemble vs  rfe WilcoxonResult(statistic=1.0, pvalue=0.14412703481601533)
# ensemble vs  shap1 WilcoxonResult(statistic=3.0, pvalue=0.3125)
# ensemble vs  shap2 WilcoxonResult(statistic=2.0, pvalue=0.1875)
# ensemble vs  ensemble2 WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='KNN'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='KNN'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=3.0, pvalue=0.3125)
# ensemble vs  feature_importance WilcoxonResult(statistic=7.0, pvalue=1.0)
# ensemble vs  rfe WilcoxonResult(statistic=0.0, pvalue=0.0625)
# ensemble vs  shap1 WilcoxonResult(statistic=3.0, pvalue=0.3125)
# ensemble vs  shap2 WilcoxonResult(statistic=7.0, pvalue=1.0)
# ensemble vs  ensemble2 WilcoxonResult(statistic=1.0, pvalue=0.28504940740261275)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='Log'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='Log'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=3.0, pvalue=0.3125)
# ensemble vs  feature_importance WilcoxonResult(statistic=6.0, pvalue=0.8125)
# ensemble vs  rfe WilcoxonResult(statistic=1.0, pvalue=0.125)
# ensemble vs  shap1 WilcoxonResult(statistic=5.0, pvalue=0.625)
# ensemble vs  shap2 WilcoxonResult(statistic=6.0, pvalue=0.8125)
# ensemble vs  ensemble2 WilcoxonResult(statistic=0.0, pvalue=0.06788915486182899)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='Ran'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='Ran'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=0.0, pvalue=0.0625)
# ensemble vs  feature_importance WilcoxonResult(statistic=7.0, pvalue=1.0)
# ensemble vs  rfe WilcoxonResult(statistic=0.0, pvalue=0.0625)
# ensemble vs  shap1 WilcoxonResult(statistic=0.0, pvalue=0.06559969214707187)
# ensemble vs  shap2 WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
# ensemble vs  ensemble2 WilcoxonResult(statistic=0.0, pvalue=0.10880943004054568)

# %%
from scipy import stats

for i in total_df.index.unique()[1:]:
    print('ensemble vs ',i, stats.wilcoxon(total_df[total_df['model']=='SVC'].loc[i, [0,1,2,3,4]] , total_df[total_df['model']=='SVC'].loc['ensemble',[0,1,2,3,4]]))
# Out:
# ensemble vs  selectkbest WilcoxonResult(statistic=1.0, pvalue=0.14412703481601533)
# ensemble vs  feature_importance WilcoxonResult(statistic=6.0, pvalue=0.8125)
# ensemble vs  rfe WilcoxonResult(statistic=2.0, pvalue=0.1875)
# ensemble vs  shap1 WilcoxonResult(statistic=0.0, pvalue=0.10880943004054568)
# ensemble vs  shap2 WilcoxonResult(statistic=5.0, pvalue=1.0)
# ensemble vs  ensemble2 WilcoxonResult(statistic=3.0, pvalue=0.4652088184521418)
